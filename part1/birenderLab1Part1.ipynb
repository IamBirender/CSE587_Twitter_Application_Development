# %% [markdown]
# # Exploratory Data Analysis & R Basics

# %% [markdown]
# ### CSE 487 Spring 2019 - Lab 1 Part 1
# #### Michael Brown - mpbrown@buffalo.edu
#
# ***Paths*** for imported data files have been modified to operate with the **zip/tar file** as the **current working directory**. For example, my Problem 4 uses the R command **getwd()** to get current working directory and build the data file path from there.
#
# Team member 1: Michael Brown (UBIT Name: mpbrown || UBIT number: 50158715)
# <br /> Team member 2: Birender Singh (UBIT Name: birender || UBIT number: 50288934)

# %% [markdown]
# ## Problem 1

# %%
#Problem 1
sales1<-c(12,14,16,29,30,45,19,20,16, 19, 34, 20)
sales2<-rpois(12,34)

par(bg="cornsilk")

plot(sales1, col="blue",type="o",ylim=c(0,100),xlab="Month",ylab="Sales")
title(main = "Sales by Month")

lines(sales2, type="o", pch=22, lty=2, col="red")
grid(nx=NA,ny=NULL)
legend("topright", inset=.05,c("Sales1","Sales2"),fill=c("blue","red"),horiz=TRUE)
# Out:
# Plot with title "Sales by Month"

# %% [markdown]
# ## Problem 2

# %%
#Problem 2
mywd <- getwd()
sales<-read.table(paste(mywd, sep="", "/salesdata.txt"), header = T)
sales
barplot(as.matrix(sales),main="Sales Data", ylab="Total",beside=T,col=rainbow(5))
# Out:
#    Sales1 Sales2
# 1  34     45
# 2  23     23
# 3  12     56
# 4  29     34
# 5  34     45
# 6  34     56
# 7  12     89
# 8  80     36
# 9  80     44
# 10 56     66
# 11 55     60
# 12 45     23
# Plot with title "Sales Data"

# %% [markdown]
# ## Problem 3

# %%
#Problem 3
fn <- boxplot(sales, col=c("orange","green"))$stats
text(1.65,fn[3,2]+2,paste("Median =", fn[3,2]), adj = 0, cex = .7)
text(0.65,fn[3,1]+2,paste("Median =", fn[3,1]), adj = 0, cex = .7)
grid(nx=NA,ny=NULL)
# Out:
# plot without title

# %% [markdown]
# ## Problem 4

# %%
#Problem 4
mywd <- getwd()
goog1 <- read.csv(paste(mywd, sep="", "/GOOG.csv"))
amzn1 <- read.csv(paste(mywd, sep="", "/AMZN.csv"))
par(bg="cornsilk")
plot(goog1$Adj.Close, col="blue",type="o",ylim=c(800,1800),xlab="Days",ylab="Price")
title(main="Google and Amazon Stocks")
lines(amzn1$Adj.Close, col="orange", type="o", pch=22, lty=2)
legend("bottomright",inset=.05,c("Google","Amazon"),fill=c("blue","orange"),horiz=TRUE)
# Out:
# Plot with title "Google and Amazon Stocks"

# %%
hist(amzn1$Adj.Close,col=rainbow(8))
# Out:
# Plot with title "Histogram of amzn1$Adj.Close"

# %% [markdown]
# ## Problem 5

# %%
#Problem 5
data()

attach(airquality)
head(airquality)
summary(airquality)
detach(airquality)

library(help=datasets)
library(datasets)
head(uspop)
plot(uspop)
# Out:
#   Ozone Solar.R Wind Temp Month Day
# 1 41    190      7.4 67   5     1
# 2 36    118      8.0 72   5     2
# 3 12    149     12.6 74   5     3
# 4 18    313     11.5 62   5     4
# 5 NA     NA     14.3 56   5     5
# 6 28     NA     14.9 66   5     6
#      Ozone           Solar.R           Wind             Temp
#  Min.   :  1.00   Min.   :  7.0   Min.   : 1.700   Min.   :56.00
#  1st Qu.: 18.00   1st Qu.:115.8   1st Qu.: 7.400   1st Qu.:72.00
#  Median : 31.50   Median :205.0   Median : 9.700   Median :79.00
#  Mean   : 42.13   Mean   :185.9   Mean   : 9.958   Mean   :77.88
#  3rd Qu.: 63.25   3rd Qu.:258.8   3rd Qu.:11.500   3rd Qu.:85.00
#  Max.   :168.00   Max.   :334.0   Max.   :20.700   Max.   :97.00
#  NA's   :37       NA's   :7
#      Month            Day
#  Min.   :5.000   Min.   : 1.0
#  1st Qu.:6.000   1st Qu.: 8.0
#  Median :7.000   Median :16.0
#  Mean   :6.993   Mean   :15.8
#  3rd Qu.:8.000   3rd Qu.:23.0
#  Max.   :9.000   Max.   :31.0
# [1]  3.93  5.31  7.24  9.64 12.90 17.10
# plot without title

# %% [markdown]
# ## Problem 6
#
# **Note:** you ***must provide your own Google API key*** in the cell below, configured for Google Maps and their Geocoding API

# %%
library("ggmap")
library("maptools")
library(maps)
register_google(key=#API KEY HERE)
visited <- c("SFO", "Chennai", "London", "Melbourne","Lima,Peru","Johannesbury, SA")
ll.visited <- geocode(visited)
visit.x <- ll.visited$lon
visit.y <- ll.visited$lat
map("world", fill=TRUE, col="white", bg="lightblue", ylim=c(-60, 90), mar=c(0,0,0,0))
points(visit.x,visit.y, col="red", pch=36)
# Out:
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=SFO&key=xxx-waWi3S8
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Chennai&key=xxx-waWi3S8
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=London&key=xxx-waWi3S8
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Melbourne&key=xxx-waWi3S8
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Lima,Peru&key=xxx-waWi3S8
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Johannesbury,+SA&key=xxx-waWi3S8
# plot without title

# %%
visited <- c("SFO", "New York", "Buffalo", "Dallas, TX")
ll.visited <- geocode(visited)
visit.x <- ll.visited$lon
visit.y <- ll.visited$lat
map("state", fill=TRUE, col=rainbow(50), bg="lightblue", mar=c(0,0,0,0))
points(visit.x,visit.y, col="yellow", pch=36)
# Out:
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=SFO&key=xxx-waWi3S8
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=New+York&key=xxx-waWi3S8
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Buffalo&key=xxx-waWi3S8
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Dallas,+TX&key=xxx-waWi3S8
# plot without title

# %% [markdown]
# ## Problem 7

# %%
#Problem 7
attach(mtcars)
head(mtcars)
plot(mtcars[c(1,3,4,5,6)], main="MTCARS Data")
plot(mtcars[c(1,3,4,6)], main="MTCARS Data")
plot(mtcars[c(1,3,4,6)], col=rainbow(5),main="MTCARS Data")
# Out:
# The following object is masked from package:ggplot2:
#
#     mpg
#                   mpg  cyl disp hp  drat wt    qsec  vs am gear carb
# Mazda RX4         21.0 6   160  110 3.90 2.620 16.46 0  1  4    4
# Mazda RX4 Wag     21.0 6   160  110 3.90 2.875 17.02 0  1  4    4
# Datsun 710        22.8 4   108   93 3.85 2.320 18.61 1  1  4    1
# Hornet 4 Drive    21.4 6   258  110 3.08 3.215 19.44 1  0  3    1
# Hornet Sportabout 18.7 8   360  175 3.15 3.440 17.02 0  0  3    2
# Valiant           18.1 6   225  105 2.76 3.460 20.22 1  0  3    1
# plot without title
# plot without title
# plot without title

# %% [markdown]
# ## Problem 8

# %%
#Problem 8
library(ggplot2)
ggplot(mtcars, aes(x=mpg, y=disp)) + geom_point()
# Out:
# plot without title
